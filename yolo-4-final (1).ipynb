# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 753.9 kB/s eta 0:00:000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.6/871.6 kB 6.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# from ultralytics import YOLO
# %cd {HOME}

# !yolo task=classify mode=train model=yolov8x-cls.pt data='/kaggle/input/yolo-4-final-2' epochs=30 imgsz=1024 device=0,1 plots=True optimize=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /kaggle/working
# ...
# 100%|█████████████████████████████████████████| 110M/110M [00:00<00:00, 274MB/s]
# Ultralytics YOLOv8.2.93 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                       CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !zip -r /kaggle/working/classify_train.zip /kaggle/working/runs/classify/train
# Out:
#   adding: kaggle/working/runs/classify/train/ (stored 0%)
#   adding: kaggle/working/runs/classify/train/confusion_matrix.png (deflated 31%)
#   adding: kaggle/working/runs/classify/train/val_batch2_labels.jpg (deflated 2%)
#   adding: kaggle/working/runs/classify/train/train_batch0.jpg (deflated 6%)
#   adding: kaggle/working/runs/classify/train/results.png (deflated 9%)
#   adding: kaggle/working/runs/classify/train/val_batch1_pred.jpg (deflated 2%)
#   adding: kaggle/working/runs/classify/train/val_batch0_labels.jpg (deflated 3%)
#   adding: kaggle/working/runs/classify/train/val_batch2_pred.jpg (deflated 2%)
#   adding: kaggle/working/runs/classify/train/train_batch10482.jpg (deflated 8%)
#   adding: kaggle/working/runs/classify/train/train_batch10481.jpg (deflated 6%)
#   adding: kaggle/working/runs/classify/train/events.out.tfevents.1726395438.ffbcf7777b9d.147.0 (deflated 93%)
#   adding: kaggle/working/runs/classify/train/weights/ (stored 0%)
# ...

# %%
import ultralytics 


# !yolo task=classify mode=predict model='/kaggle/working/runs/classify/train/weights/best.pt' source='/kaggle/input/testing-images/testing_images' imgsz=1024
# Out:
# Ultralytics YOLOv8.2.93 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8x-cls summary (fused): 133 layers, 56,128,324 parameters, 0 gradients, 153.8 GFLOPs
#
# image 1/723 /kaggle/input/testing-images/testing_images/tt11020728_jpg.rf.8320b861012810b8c2d6ceb32e36f3fc.jpg: 1024x1024 Romance 1.00, Action 0.00, Animation 0.00, Horror 0.00, 87.5ms
# image 2/723 /kaggle/input/testing-images/testing_images/tt11083552_jpg.rf.9946e4a800bf8d506482446d4aa07e2f.jpg: 1024x1024 Action 0.98, Animation 0.02, Horror 0.00, Romance 0.00, 81.9ms
# image 3/723 /kaggle/input/testing-images/testing_images/tt11138512_jpg.rf.8d7decbd747038de6ccb39fba8618a2d.jpg: 1024x1024 Action 0.73, Animation 0.27, Romance 0.00, Horror 0.00, 81.2ms
# image 4/723 /kaggle/input/testing-images/testing_images/tt1160419_jpg.rf.777e390dcf4c1f4b2dd60d4191740a70.jpg: 1024x1024 Action 1.00, Romance 0.00, Animation 0.00, Horror 0.00, 79.4ms
# ...
