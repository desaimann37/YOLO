# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.1/873.1 kB 6.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# tuple = (377, 512)

from ultralytics import YOLO
# %cd {HOME}

# !yolo task=classify mode=train model=yolov8x-cls.pt data='/kaggle/input/yolo-4-final-3/YOLO_4_Final3' epochs=30 imgsz=754,1024 device=0,1 plots=True optimize=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /kaggle/working
# ...
# 100%|████████████████████████████████████████| 110M/110M [00:02<00:00, 50.3MB/s]
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                       CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r /kaggle/working/runs/classify/train.zip /kaggle/working/runs/classify/train
# Out:
#   adding: kaggle/working/runs/classify/train/ (stored 0%)
#   adding: kaggle/working/runs/classify/train/train_batch10640.jpg (deflated 7%)
#   adding: kaggle/working/runs/classify/train/val_batch1_labels.jpg (deflated 2%)
#   adding: kaggle/working/runs/classify/train/confusion_matrix_normalized.png (deflated 29%)
#   adding: kaggle/working/runs/classify/train/train_batch1.jpg (deflated 6%)
#   adding: kaggle/working/runs/classify/train/val_batch0_labels.jpg (deflated 3%)
#   adding: kaggle/working/runs/classify/train/val_batch0_pred.jpg (deflated 3%)
#   adding: kaggle/working/runs/classify/train/train_batch0.jpg (deflated 6%)
#   adding: kaggle/working/runs/classify/train/args.yaml (deflated 51%)
#   adding: kaggle/working/runs/classify/train/train_batch10642.jpg (deflated 8%)
#   adding: kaggle/working/runs/classify/train/val_batch1_pred.jpg (deflated 2%)
#   adding: kaggle/working/runs/classify/train/train_batch2.jpg (deflated 9%)
# ...

# %%
#For Tomorrow: 



# tuple = (377, 512)

from ultralytics import YOLO
# %cd {HOME}

# !yolo task=classify mode=train model=yolov8x-cls.pt data='/kaggle/input/yolo-tomorrow/YOLO_2_1_Augmented' epochs=30 imgsz=512 device=0,1 plots=True optimize=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /kaggle/working
# ...
# 100%|█████████████████████████████████████████| 110M/110M [00:00<00:00, 133MB/s]
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                       CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r /kaggle/working/runs/classify/train.zip /kaggle/working/runs/classify/train
# Out:
#   adding: kaggle/working/runs/classify/train/ (stored 0%)
#   adding: kaggle/working/runs/classify/train/confusion_matrix_normalized.png (deflated 28%)
#   adding: kaggle/working/runs/classify/train/val_batch2_pred.jpg (deflated 3%)
#   adding: kaggle/working/runs/classify/train/val_batch1_labels.jpg (deflated 2%)
#   adding: kaggle/working/runs/classify/train/results.png (deflated 9%)
#   adding: kaggle/working/runs/classify/train/train_batch2.jpg (deflated 5%)
#   adding: kaggle/working/runs/classify/train/confusion_matrix.png (deflated 31%)
#   adding: kaggle/working/runs/classify/train/args.yaml (deflated 51%)
#   adding: kaggle/working/runs/classify/train/train_batch0.jpg (deflated 4%)
#   adding: kaggle/working/runs/classify/train/val_batch0_pred.jpg (deflated 2%)
#   adding: kaggle/working/runs/classify/train/val_batch1_pred.jpg (deflated 2%)
#   adding: kaggle/working/runs/classify/train/results.csv (deflated 86%)
# ...

# %%
from ultralytics import YOLO

# !yolo task=classify mode=predict model='/kaggle/input/pretrained_model/other/default/1/best.pt' source='/kaggle/input/test-sir-3/testing_sir2' imgsz=512
# Out:
# Ultralytics YOLOv8.2.97 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8x-cls summary (fused): 133 layers, 56,128,324 parameters, 0 gradients, 153.8 GFLOPs
#
# image 1/57 /kaggle/input/test-sir-3/testing_sir2/a10_PNG.rf.e83608caead0834247dad43357c8464e.jpg: 1024x1024 Horror 1.00, Romance 0.00, Animation 0.00, Action 0.00, 120.5ms
# image 2/57 /kaggle/input/test-sir-3/testing_sir2/a11_PNG.rf.c986de29b826b5e0b0d6a2f9ea287cf2.jpg: 1024x1024 Horror 0.97, Romance 0.03, Animation 0.00, Action 0.00, 99.9ms
# image 3/57 /kaggle/input/test-sir-3/testing_sir2/a12_PNG.rf.76c18990692094e80771ba5372c25b3a.jpg: 1024x1024 Horror 1.00, Romance 0.00, Animation 0.00, Action 0.00, 88.3ms
# image 4/57 /kaggle/input/test-sir-3/testing_sir2/a13_PNG.rf.c1d105d3a83cfcbd715f0feed7dffd64.jpg: 1024x1024 Horror 0.97, Romance 0.03, Animation 0.00, Action 0.00, 75.0ms
# ...
